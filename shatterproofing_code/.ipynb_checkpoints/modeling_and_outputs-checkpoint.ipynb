# %%
# packages
import numpy as np
import pandas as pd
import scipy.stats as sc
import matplotlib.pyplot as plt
from options_wrangler import OptionsWrangler

# %%
# data loading
d_loc = 'csv_data/'
ytw = pd.read_csv(d_loc + 'ytw.csv')
ytw['ytw'] = ytw['ytw'].str.rstrip('%').astype('float') / 100.0
ytw['date'] = pd.to_datetime(ytw['date'])
ytm = pd.read_csv(d_loc + 'ytm.csv')
ytm['ytm'] = ytm['ytm'].str.rstrip('%').astype('float') / 100.0;
ytm['date'] = pd.to_datetime(ytm['date'])
expos = pd.read_csv(d_loc + "expos.csv")
expos['date'] = pd.to_datetime(expos['date'])
uso = pd.read_csv(d_loc + 'uso.csv')
uso['trade_date'] = pd.to_datetime(uso['trade_date'])
uso['expirDate'] = pd.to_datetime(uso['expirDate'])
uso_stock = uso[['trade_date', 'stkPx']].groupby('trade_date').agg(np.mean)
monthly_expos = expos[expos.expo_type == 'Monthly']
max_date_back = max([
    min(uso_stock.index), 
    min(monthly_expos['date']), 
    min(ytm['date']), 
    min(ytw['date'])])

uso = uso[uso["trade_date"] >  max_date_back]

# %%
uso.head(), max_date_back
# Out:
# (        stkPx trade_date  expirDate  strike  cOi    pOi  cValue  pValue  \
#  210074  41.24 2010-04-01 2010-04-16    18.0   50   1040   23.24     0.0
#  210075  41.24 2010-04-01 2010-04-16    19.0   50   2407   22.24     0.0
#  210076  41.24 2010-04-01 2010-04-16    20.0   10   2292   21.24     0.0
#  210077  41.24 2010-04-01 2010-04-16    21.0    0  25400   20.24     0.0
#  210078  41.24 2010-04-01 2010-04-16    22.0    0  21096   19.24     0.0
#
#          delta  gamma
#  210074    1.0    0.0
#  210075    1.0    0.0
#  210076    1.0    0.0
#  210077    1.0    0.0
#  210078    1.0    0.0  , Timestamp('2010-03-31 00:00:00'))

# %%
#### USO Sorting
# putting into one frame
# pd.merge
# pd.shift (for advancing)
uso_expos = monthly_expos.merge(uso, left_on='date', right_on='expirDate')
uso_expos = uso_expos.drop(columns=['date', 'expo_type'])
uso_trading = monthly_expos.merge(uso_expos, left_on='date', right_on='trade_date')
uso_trading = uso_trading.sort_values(['trade_date', 'expirDate', 'strike'])

# %%
min(np.unique(uso_trading.trade_date)), min(np.unique(uso.trade_date)), min(np.unique(monthly_expos.date))
# Out:
# (numpy.datetime64('2010-12-17T00:00:00.000000000'),
#  numpy.datetime64('2010-04-01T00:00:00.000000000'),
#  numpy.datetime64('2007-01-20T00:00:00.000000000'))

# %%
# building a model on linear regression time series 
# https://towardsdatascience.com/prediction-task-with-multivariate-timeseries-and-var-model-47003f629f9

# %% [markdown]
# ### Plotting YTM & YTW
# This is to visualize the estimated cost of a goverment paying the TEY of the S&P IG Energy Sector YTM & YTW and buying the 20 delta USO put for two months out.

# %%
max_date_back
# Out:
# Timestamp('2010-04-01 00:00:00')

# %%
delta = .2
put_delta = 1 - delta
first_trade, trade_pass = True, True
for trade_date, chain in uso_trading.groupby('trade_date'):
    first_trade = True
    for expirDate, expo_chain in chain.groupby('expirDate'):
        if first_trade: 
            first_trade = False
            trade_pass = False
            continue
        elif trade_pass:
            break
        else:
            right_delta = expo_chain.iloc[(expo_chain['delta'] - put_delta).abs().argsort()[:1]]
            right_cols = right_delta[['trade_date', 'expirDate', 'pValue', 'strike', 'delta']]
            print(right_cols)
            trade_pass = True
# Out:
#    trade_date  expirDate  pValue  strike   delta
# 47 2010-12-17 2011-01-21    0.38    35.0  0.8112
#     trade_date  expirDate  pValue  strike   delta
# 283 2011-01-21 2011-02-18     0.3    35.0  0.8204
#     trade_date  expirDate  pValue  strike   delta
# 468 2011-02-18 2011-03-18    0.27    34.0  0.8241
#     trade_date  expirDate  pValue  strike   delta
# 675 2011-03-18 2011-04-15     0.6    38.0  0.7754
#      trade_date  expirDate  pValue  strike  delta
# 1002 2011-04-15 2011-05-20    0.53    41.0  0.777
#      trade_date  expirDate  pValue  strike   delta
# 1282 2011-05-20 2011-06-17    0.44    36.0  0.8193
#      trade_date  expirDate  pValue  strike   delta
# 1567 2011-06-17 2011-07-15    0.49    34.0  0.7822
#      trade_date  expirDate  pValue  strike   delta
# 1857 2011-07-15 2011-08-19    0.41    35.0  0.8153
#      trade_date  expirDate  pValue  strike   delta
# 2121 2011-08-19 2011-09-16    0.59    28.0  0.8164
#      trade_date  expirDate  pValue  strike   delta
# 2410 2011-09-16 2011-10-21    0.54    30.0  0.8221
#      trade_date  expirDate  pValue  strike   delta
# 2759 2011-10-21 2011-11-18    0.56    30.0  0.8127
#      trade_date  expirDate  pValue  strike   delta
# 3111 2011-11-18 2011-12-16    0.47    34.0  0.8243
#      trade_date  expirDate  pValue  strike   delta
# 3426 2011-12-16 2012-01-20    0.61    33.0  0.7858
#      trade_date  expirDate  pValue  strike   delta
# 3692 2012-01-20 2012-02-17    0.37    35.0  0.8122
#      trade_date  expirDate  pValue  strike  delta
# 4001 2012-02-17 2012-03-16    0.34    37.0   0.82
#      trade_date  expirDate  pValue  strike   delta
# 4313 2012-03-16 2012-04-20    0.35    38.0  0.8249
#      trade_date  expirDate  pValue  strike  delta
# 4600 2012-04-20 2012-05-18    0.33    37.0  0.808
#      trade_date  expirDate  pValue  strike   delta
# 4842 2012-05-18 2012-06-15    0.39    32.0  0.7966
#      trade_date  expirDate  pValue  strike   delta
# 5105 2012-06-15 2012-07-20     0.5    29.0  0.7836
#      trade_date  expirDate  pValue  strike   delta
# 5404 2012-07-20 2012-08-17    0.43    32.0  0.7761
#      trade_date  expirDate  pValue  strike   delta
# 5754 2012-08-17 2012-09-21    0.44    33.5  0.7843
#      trade_date  expirDate  pValue  strike   delta
# 6114 2012-09-21 2012-10-19    0.35    32.0  0.8064
#      trade_date  expirDate  pValue  strike   delta
# 6505 2012-10-19 2012-11-16    0.41    31.0  0.7882
#      trade_date  expirDate  pValue  strike   delta
# 6903 2012-11-16 2012-12-21    0.35    29.5  0.8066
#      trade_date  expirDate  pValue  strike   delta
# 7299 2012-12-21 2013-01-18    0.23    30.0  0.8373
#      trade_date  expirDate  pValue  strike   delta
# 7690 2013-01-18 2013-02-15    0.24    33.0  0.8074
#      trade_date  expirDate  pValue  strike  delta
# 8110 2013-02-15 2013-03-15    0.26    33.0  0.796
#      trade_date  expirDate  pValue  strike  delta
# 8543 2013-03-15 2013-04-19    0.27    32.0  0.788
#      trade_date  expirDate  pValue  strike  delta
# 8976 2013-04-19 2013-05-17    0.33    29.5  0.788
#      trade_date  expirDate  pValue  strike  delta
# 9347 2013-05-17 2013-06-21    0.28    32.0  0.814
#      trade_date  expirDate  pValue  strike   delta
# 9717 2013-06-21 2013-07-19    0.31    31.5  0.7823
#       trade_date  expirDate  pValue  strike   delta
# 10042 2013-07-19 2013-08-16    0.31    36.5  0.7939
#       trade_date  expirDate  pValue  strike   delta
# 10287 2013-08-16 2013-09-20     0.3    36.0  0.8156
#       trade_date  expirDate  pValue  strike   delta
# 10564 2013-09-20 2013-10-18    0.27    36.0  0.7951
#       trade_date  expirDate  pValue  strike   delta
# 10874 2013-10-18 2013-11-15    0.21    34.5  0.8298
#       trade_date  expirDate  pValue  strike   delta
# 11214 2013-11-15 2013-12-20    0.24    32.0  0.8115
#       trade_date  expirDate  pValue  strike   delta
# 11561 2013-12-20 2014-01-17    0.19    34.0  0.8103
#       trade_date  expirDate  pValue  strike   delta
# 11886 2014-01-17 2014-02-21    0.22    32.0  0.8151
#       trade_date  expirDate  pValue  strike   delta
# 12199 2014-02-21 2014-03-21    0.18    35.0  0.8307
#       trade_date  expirDate  pValue  strike   delta
# 12500 2014-03-21 2014-05-16     0.3    33.5  0.8155
#       trade_date  expirDate  pValue  strike   delta
# 12801 2014-04-17 2014-06-20    0.39    35.5  0.7833
#       trade_date  expirDate  pValue  strike   delta
# 13060 2014-05-16 2014-06-20    0.25    36.0  0.7682
#       trade_date  expirDate  pValue  strike   delta
# 13377 2014-06-20 2014-07-18    0.21    38.0  0.7901
#       trade_date  expirDate  pValue  strike  delta
# 13693 2014-07-18 2014-08-15     0.2    36.5  0.785
#       trade_date  expirDate  pValue  strike   delta
# 13994 2014-09-19 2014-10-17    0.17    33.0  0.8246
#       trade_date  expirDate  pValue  strike   delta
# 14322 2014-10-17 2014-11-21    0.43    29.0  0.7805
#       trade_date  expirDate  pValue  strike   delta
# 14684 2014-11-21 2014-12-19    0.36    27.0  0.7898
#       trade_date  expirDate  pValue  strike   delta
# 15044 2014-12-19 2015-01-16    0.35    19.0  0.8316
#       trade_date  expirDate  pValue  strike   delta
# 15442 2015-01-16 2015-02-20    0.38    16.0  0.8045
#       trade_date  expirDate  pValue  strike   delta
# 15885 2015-02-20 2015-03-20    0.35    16.5  0.8039
#       trade_date  expirDate  pValue  strike  delta
# 16320 2015-03-20 2015-04-17    0.36    15.0  0.759
#       trade_date  expirDate  pValue  strike   delta
# 16795 2015-04-17 2015-05-15    0.25    18.0  0.8157
#       trade_date  expirDate  pValue  strike   delta
# 17178 2015-05-15 2015-06-19    0.25    19.0  0.7949
#       trade_date  expirDate  pValue  strike   delta
# 17550 2015-06-19 2015-07-17    0.24    19.0  0.7578
#       trade_date  expirDate  pValue  strike   delta
# 17917 2015-07-17 2015-08-21    0.23    15.5  0.8003
#       trade_date  expirDate  pValue  strike   delta
# 18245 2015-08-21 2015-09-18     0.2    12.0  0.7971
#       trade_date  expirDate  pValue  strike   delta
# 18587 2015-09-18 2015-10-16    0.18    13.0  0.8295
#       trade_date  expirDate  pValue  strike  delta
# 18963 2015-10-16 2015-11-20    0.27    14.0  0.772
#       trade_date  expirDate  pValue  strike   delta
# 19327 2015-11-20 2015-12-18    0.15    11.5  0.8397
#       trade_date  expirDate  pValue  strike   delta
# 19672 2015-12-18 2016-01-15    0.16     9.5  0.8173
#       trade_date  expirDate  pValue  strike  delta
# 20051 2016-01-15 2016-02-19    0.18     7.5  0.821
#       trade_date  expirDate  pValue  strike   delta
# 20408 2016-02-19 2016-03-18    0.19     7.5  0.7979
#       trade_date  expirDate  pValue  strike   delta
# 20747 2016-03-18 2016-04-15    0.15     9.5  0.8028
#       trade_date  expirDate  pValue  strike   delta
# 21115 2016-04-15 2016-05-20    0.19     9.0  0.8114
#       trade_date  expirDate  pValue  strike   delta
# 21412 2016-05-20 2016-06-17    0.13    10.5  0.8358
#       trade_date  expirDate  pValue  strike   delta
# 21703 2016-06-17 2016-07-15    0.15    10.5  0.8174
#       trade_date  expirDate  pValue  strike   delta
# 22017 2016-07-15 2016-08-19    0.16    10.0  0.7978
#       trade_date  expirDate  pValue  strike   delta
# 22314 2016-08-19 2016-09-16    0.17    10.5  0.7756
#       trade_date  expirDate  pValue  strike   delta
# 22596 2016-09-16 2016-10-21    0.16     9.0  0.8044
#       trade_date  expirDate  pValue  strike   delta
# 22899 2016-10-21 2016-11-18    0.09    10.5  0.8467
#       trade_date  expirDate  pValue  strike   delta
# 23191 2016-11-18 2016-12-16    0.12     9.0  0.8496
#       trade_date  expirDate  pValue  strike   delta
# 23497 2016-12-16 2017-01-20     0.1    10.5  0.8438
#       trade_date  expirDate  pValue  strike   delta
# 23820 2017-01-20 2017-02-17     0.1    10.5  0.8309
#       trade_date  expirDate  pValue  strike   delta
# 24099 2017-02-17 2017-03-17    0.05    10.5  0.8791
#       trade_date  expirDate  pValue  strike   delta
# 24394 2017-03-17 2017-04-21    0.08     9.5  0.8395
#       trade_date  expirDate  pValue  strike   delta
# 24681 2017-04-21 2017-05-19    0.07     9.5  0.8468
#       trade_date  expirDate  pValue  strike   delta
# 24932 2017-05-19 2017-06-16    0.16    10.0  0.7244
#       trade_date  expirDate  pValue  strike   delta
# 25171 2017-06-16 2017-07-21    0.08     8.5  0.8283
#       trade_date  expirDate  pValue  strike   delta
# 25414 2017-07-21 2017-08-18    0.05     8.5  0.8843
#       trade_date  expirDate  pValue  strike   delta
# 25639 2017-08-18 2017-09-15    0.12     9.5  0.7407
#       trade_date  expirDate  pValue  strike   delta
# 25856 2017-09-15 2017-10-20    0.09     9.5  0.8091
#       trade_date  expirDate  pValue  strike   delta
# 26078 2017-10-20 2017-11-17    0.11    10.0  0.7525
#       trade_date  expirDate  pValue  strike  delta
# 26284 2017-11-17 2017-12-15    0.13    11.0  0.707
#       trade_date  expirDate  pValue  strike   delta
# 26520 2017-12-15 2018-01-19    0.11    11.0  0.7562
#       trade_date  expirDate  pValue  strike   delta
# 26745 2018-01-19 2018-02-16    0.06    12.0  0.8443
#       trade_date  expirDate  pValue  strike   delta
# 26939 2018-02-16 2018-03-16    0.07    11.5  0.8502
#       trade_date  expirDate  pValue  strike   delta
# 27166 2018-03-16 2018-04-20    0.14    12.0  0.7512
#       trade_date  expirDate  pValue  strike   delta
# 27362 2018-04-20 2018-05-18    0.13    13.0  0.7877
#       trade_date  expirDate  pValue  strike   delta
# 27560 2018-05-18 2018-06-15    0.07    13.5  0.8545
#       trade_date  expirDate  pValue  strike   delta
# 27724 2018-06-15 2018-07-20     0.1    12.0  0.8416
#       trade_date  expirDate  pValue  strike   delta
# 27882 2018-07-20 2018-08-17    0.14    13.5  0.7678
#       trade_date  expirDate  pValue  strike   delta
# 28050 2018-08-17 2018-09-21    0.18    13.0  0.7507
#       trade_date  expirDate  pValue  strike   delta
# 28196 2018-09-21 2018-10-19     0.1    14.0  0.8281
#       trade_date  expirDate  pValue  strike   delta
# 28368 2018-10-19 2018-11-16    0.17    14.0  0.7571
#       trade_date  expirDate  pValue  strike   delta
# 28566 2018-11-16 2018-12-21    0.22    11.0  0.7745
#       trade_date  expirDate  pValue  strike   delta
# 28802 2018-12-21 2019-01-18    0.17     8.5  0.8059
#       trade_date  expirDate  pValue  strike   delta
# 29062 2019-01-18 2019-02-15    0.14    10.5  0.7938
#       trade_date  expirDate  pValue  strike   delta
# 29300 2019-02-15 2019-03-15    0.15    11.0  0.7697
#       trade_date  expirDate  pValue  strike   delta
# 29511 2019-03-15 2019-04-18    0.17    11.5  0.7567
#       trade_date  expirDate  pValue  strike   delta
# 29761 2019-04-18 2019-05-17    0.12    12.5  0.8043
#       trade_date  expirDate  pValue  strike    delta
# 30011 2019-05-17 2019-06-21    0.07    12.0  0.86634
#       trade_date  expirDate  pValue  strike     delta
# 30428 2019-06-21 2019-07-19    0.21    11.0  0.768557
#       trade_date  expirDate  pValue  strike     delta
# 30798 2019-07-19 2019-08-16    0.18    11.0  0.748938
#       trade_date  expirDate  pValue  strike     delta
# 31244 2019-08-16 2019-09-20    0.18    10.5  0.776089
#       trade_date  expirDate  pValue  strike  delta
# 31584 2019-09-20 2019-10-18    0.09    11.0  0.861
#       trade_date  expirDate  pValue  strike     delta
# 31789 2019-10-18 2019-11-15    0.17    10.5  0.762175
#       trade_date  expirDate  pValue  strike     delta
# 31983 2019-11-15 2019-12-20    0.12    11.0  0.828127
#       trade_date  expirDate  pValue  strike     delta
# 32155 2019-12-20 2020-01-17    0.14    12.0  0.764763
#       trade_date  expirDate  pValue  strike     delta
# 32340 2020-01-17 2020-02-21    0.05    11.0  0.909777
#       trade_date  expirDate  pValue  strike   delta
# 32517 2020-02-21 2020-03-20    0.11    10.0  0.8466
#       trade_date  expirDate  pValue  strike   delta
# 32676 2020-03-20 2020-04-17    0.54     4.0  0.7436

# %%
wrangler = OptionsWrangler(data=options_data)
# returns the expiration chain for an option, either for a particular month or for a full chain
wrangler.get_expo_chain(expo_chain, trade_date) # throws not valid expo, not in dataset (before, after)
# returns the daily data for an option
wrangler.get_option_history(strike, expo, starting_trade_date) # throws no such option, not in dataset
# gets the histoprical chains for a month of options
wrangler.get_days_historical_chain() # throws not in data set
# gets the implied volatility for trade date and month, returns the smile data
wrangler.get_imp_vol(expo, trade_date)
# gets the value of a call at a particular strike
wrangler.get_call_value(expo, trade_date, strike) # throws not in dataset 
# gets the value of a put at a particular strike
wrangler.get_put_value(expo, trade_date, strike) # throws not in dataset
# gets the market, with sizes for a particular option
wrangler.get_market(expo, trade_date, strike, side) # throws not in dataset
# Out:
#   File "<ipython-input-4-dbb889a63519>", line 5
#     Option((delta or strike) and trade_date and expo, months_out=None, weeks_out=None,)
#     ^
# IndentationError: unexpected indent

# %%
uso = pd.read_csv(d_loc + 'uso.csv')
uso['trade_date'] = pd.to_datetime(uso['trade_date'])
uso['expirDate'] = pd.to_datetime(uso['expirDate'])
uso_set = uso.set_index(['trade_date', 'expirDate', 'strike']);

# %%
uso_wrangler = OptionsWrangler(data=d_loc + 'uso.csv')

# %%
trade_date = pd.to_datetime('2020-02-14')
expo = pd.to_datetime('2020-04-17')
strike = 12.0

# %%
# %timeit uso.query(f"trade_date == '2020-02-14' and expirDate == '2020-04-17' and strike == 12.0")
# Out:
# 25 ms ± 174 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
uso.reset_index();

# %%
# %timeit uso.query(f"trade_date == '2020-02-14' and expirDate == '2020-04-17' and strike == 12.0")
# Out:
# 24.4 ms ± 266 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
    # %timeit uso.query("'2020-02-14' < trade_date < '2020-03-15' and expirDate == '2020-04-17' and strike == 12.0 ")
# Out:
# 32.3 ms ± 200 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
v = uso.query("'2019-11-20' < trade_date < '2020-03-15' and expirDate == '2020-04-17' and strike == 8")

# %%
# %timeit uso_set.query("'2018-11-20' < trade_date < '2020-03-15' and expirDate == '2020-04-17' and strike == 10.0 ")
# Out:
# 68.2 ms ± 585 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit uso.query("'2018-11-20' < trade_date < '2020-03-15' and expirDate == '2020-04-17' and strike == 10.0 ")
# Out:
# 32.2 ms ± 449 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
uso_wrangler.get_expo_chain('2020-02-14', '2020-04-17')
# Out:
#                        strike  stkPx    cOi    pOi  cValue  pValue   delta  \
# trade_date expirDate
# 2020-02-14 2020-04-17     1.0  10.94      2      0    9.94    0.00  1.0000
#            2020-04-17     2.0  10.94      0      0    8.95    0.00  1.0000
#            2020-04-17     3.0  10.94      0      5    7.95    0.00  1.0000
#            2020-04-17     4.0  10.94      0      0    6.95    0.00  1.0000
#            2020-04-17     5.0  10.94      3      4    5.96    0.00  1.0000
#            2020-04-17     5.5  10.94      0      0    5.46    0.00  1.0000
#            2020-04-17     6.0  10.94      0      0    4.96    0.00  0.9999
#            2020-04-17     6.5  10.94      0    119    4.46    0.00  0.9995
#            2020-04-17     7.0  10.94     18    142    3.96    0.00  0.9978
#            2020-04-17     7.5  10.94      2    257    3.47    0.00  0.9926
#            2020-04-17     8.0  10.94    130    590    2.98    0.01  0.9793
#            2020-04-17     8.5  10.94     31   1080    2.50    0.04  0.9536
#            2020-04-17     9.0  10.94    649  20111    2.04    0.08  0.9106
#            2020-04-17     9.5  10.94    286  21005    1.61    0.14  0.8466
#            2020-04-17    10.0  10.94  21047  56104    1.22    0.25  0.7599
#            2020-04-17    10.5  10.94   2314  30720    0.87    0.39  0.6495
#            2020-04-17    11.0  10.94  28968  26755    0.58    0.60  0.5195
#            2020-04-17    11.5  10.94  17686   7379    0.36    0.88  0.3833
#            2020-04-17    12.0  10.94  65316  25099    0.21    1.24  0.2605
#            2020-04-17    12.5  10.94  10343   5535    0.11    1.65  0.1646
#            2020-04-17    13.0  10.94  38337   9906    0.06    2.10  0.0978
#            2020-04-17    13.5  10.94   4935    731    0.03    2.57  0.0548
#            2020-04-17    14.0  10.94   6496    799    0.01    3.06  0.0293
#            2020-04-17    14.5  10.94   2792    330    0.01    3.56  0.0148
#            2020-04-17    15.0  10.94   5291     71    0.00    4.06  0.0072
#            2020-04-17    15.5  10.94   1882     26    0.00    4.56  0.0033
#            2020-04-17    16.0  10.94  16740     57    0.00    5.06  0.0015
#            2020-04-17    16.5  10.94   1235      0    0.00    5.56  0.0006
#            2020-04-17    17.0  10.94   3443     10    0.00    6.06  0.0003
#            2020-04-17    17.5  10.94   1990      0    0.00    6.56  0.0001
#            2020-04-17    18.0  10.94   2136      0    0.00    7.06  0.0000
#            2020-04-17    19.0  10.94   6211      0    0.00    8.06  0.0000
#            2020-04-17    20.0  10.94   7860      0    0.00    9.06  0.0000
#            2020-04-17    21.0  10.94   1590      0    0.00   10.06  0.0000
#
#                        gamma
# trade_date expirDate
# 2020-02-14 2020-04-17  0.000
#            2020-04-17  0.000
#            2020-04-17  0.000
#            2020-04-17  0.000
#            2020-04-17  0.000
#            2020-04-17  0.000
#            2020-04-17  0.000
#            2020-04-17  0.001
#            2020-04-17  0.004
#            2020-04-17  0.012
#            2020-04-17  0.028
#            2020-04-17  0.056
#            2020-04-17  0.094
#            2020-04-17  0.142
#            2020-04-17  0.194
#            2020-04-17  0.242
#            2020-04-17  0.272
#            2020-04-17  0.270
#            2020-04-17  0.234
#            2020-04-17  0.181
#            2020-04-17  0.126
#            2020-04-17  0.081
#            2020-04-17  0.049
#            2020-04-17  0.027
#            2020-04-17  0.014
#            2020-04-17  0.007
#            2020-04-17  0.004
#            2020-04-17  0.002
#            2020-04-17  0.001
#            2020-04-17  0.000
#            2020-04-17  0.000
#            2020-04-17  0.000
#            2020-04-17  0.000
#            2020-04-17  0.000

# %%
# Out:
#                        strike  stkPx    cOi    pOi  cValue  pValue     delta  \
# trade_date expirDate
# 2019-11-21 2020-04-17    10.0  12.20    401  25531    2.47    0.26  0.837303
# 2019-11-22 2020-04-17    10.0  12.10    400  25454    2.37    0.26  0.831497
# 2019-11-25 2020-04-17    10.0  12.12    400  25454    2.39    0.26  0.833385
# 2019-11-26 2020-04-17    10.0  12.18    395  25454    2.44    0.25  0.840356
# 2019-11-27 2020-04-17    10.0  12.14    395  25454    2.40    0.25  0.836719
# 2019-11-29 2020-04-17    10.0  11.61    396  25474    1.97    0.36  0.780600
# 2019-12-02 2020-04-17    10.0  11.69    401  25474    2.03    0.33  0.791868
# 2019-12-03 2020-04-17    10.0  11.74    401  25483    2.06    0.30  0.802788
# 2019-12-04 2020-04-17    10.0  12.18    402  25553    2.44    0.25  0.839317
# 2019-12-05 2020-04-17    10.0  12.19    422  25593    2.47    0.23  0.851738
# 2019-12-06 2020-04-17    10.0  12.34    417  25590    2.61    0.21  0.862275
# 2019-12-09 2020-04-17    10.0  12.32    419  25589    2.56    0.19  0.870371
# 2019-12-10 2020-04-17    10.0  12.39    418  25589    2.62    0.17  0.877653
# 2019-12-11 2020-04-17    10.0  12.30    419  25594    2.53    0.17  0.873605
# 2019-12-12 2020-04-17    10.0  12.40    419  25570    2.62    0.16  0.881635
# 2019-12-13 2020-04-17    10.0  12.48    419  25545    2.68    0.15  0.889354
# 2019-12-16 2020-04-17    10.0  12.60    418  25545    2.78    0.13  0.899943
# 2019-12-17 2020-04-17    10.0  12.72    418  25550    2.89    0.12  0.909004
# 2019-12-18 2020-04-17    10.0  12.73    421  25566    2.87    0.09  0.922939
# 2019-12-19 2020-04-17    10.0  12.77    421  20566    2.93    0.11  0.911845
# 2019-12-20 2020-04-17    10.0  12.62    421  20566    2.79    0.12  0.907219
# 2019-12-23 2020-04-17    10.0  12.70    421  21073    2.84    0.09  0.919661
# 2019-12-24 2020-04-17    10.0  12.77    423  21073    2.91    0.09  0.925022
# 2019-12-26 2020-04-17    10.0  12.91    423  21073    2.99    0.07  0.933223
# 2019-12-27 2020-04-17    10.0  12.90    423  21060    3.01    0.07  0.938457
# 2019-12-30 2020-04-17    10.0  12.89    425  21060    3.02    0.08  0.931589
# 2019-12-31 2020-04-17    10.0  12.81    425  21059    2.95    0.09  0.924439
# 2020-01-02 2020-04-17    10.0  12.80    425  21059    2.93    0.08  0.927357
# 2020-01-03 2020-04-17    10.0  13.19    435  21016    3.30    0.06  0.945860
# 2020-01-06 2020-04-17    10.0  13.14    436  21040    3.25    0.07  0.940763
# ...                       ...    ...    ...    ...     ...     ...       ...
# 2020-01-31 2020-04-17    10.0  10.82  12795  30559    1.25    0.41  0.704774
# 2020-02-03 2020-04-17    10.0  10.51  19300  30795    1.02    0.49  0.648664
# 2020-02-04 2020-04-17    10.0  10.44  20894  31251    0.95    0.48  0.639744
# 2020-02-05 2020-04-17    10.0  10.72  21149  58890    1.13    0.38  0.698676
# 2020-02-06 2020-04-17    10.0  10.72  21047  58975    1.12    0.38  0.695507
# 2020-02-07 2020-04-17    10.0  10.59  20974  60887    1.00    0.39  0.676640
# 2020-02-10 2020-04-17    10.0  10.40  21722  62114    0.89    0.45  0.637345
# 2020-02-11 2020-04-17    10.0  10.47  20947  63949    0.91    0.41  0.651626
# 2020-02-12 2020-04-17    10.0  10.82  21096  64802    1.13    0.28  0.737007
# 2020-02-13 2020-04-17    10.0  10.85  20997  57093    1.17    0.31  0.727888
# 2020-02-14 2020-04-17    10.0  10.94  21047  56104    1.22    0.25  0.759900
# 2020-02-18 2020-04-17    10.0  10.94  20938  54616    1.19    0.22  0.768700
# 2020-02-19 2020-04-17    10.0  11.18  20968  54589    1.36    0.15  0.821600
# 2020-02-20 2020-04-17    10.0  11.27  21011  54599    1.44    0.15  0.831700
# 2020-02-21 2020-04-17    10.0  11.16  10250  54576    1.35    0.17  0.808900
# 2020-02-24 2020-04-17    10.0  10.74   8905  58177    1.05    0.28  0.722800
# 2020-02-25 2020-04-17    10.0  10.41   8633  58339    0.86    0.42  0.642100
# 2020-02-26 2020-04-17    10.0  10.19   8437  60049    0.71    0.49  0.588100
# 2020-02-27 2020-04-17    10.0   9.82   8605  60706    0.53    0.69  0.488300
# 2020-02-28 2020-04-17    10.0   9.43   9361  61720    0.38    0.94  0.391000
# 2020-03-02 2020-04-17    10.0   9.86  10754  61575    0.56    0.68  0.500100
# 2020-03-03 2020-04-17    10.0   9.93  10925  61795    0.61    0.69  0.514700
# 2020-03-04 2020-04-17    10.0   9.86  16734  62507    0.56    0.70  0.498100
# 2020-03-05 2020-04-17    10.0   9.59  16728  62955    0.44    0.85  0.428200
# 2020-03-06 2020-04-17    10.0   8.64  16516  62848    0.20    1.55  0.236800
# 2020-03-09 2020-04-17    10.0   6.54  22005  64204    0.08    3.54  0.101800
# 2020-03-10 2020-04-17    10.0   7.27  30324  52794    0.07    2.80  0.094900
# 2020-03-11 2020-04-17    10.0   6.88  34566  43562    0.04    3.15  0.064200
# 2020-03-12 2020-04-17    10.0   6.53  34634  43520    0.05    3.52  0.072000
# 2020-03-13 2020-04-17    10.0   6.68  34670  43483    0.06    3.37  0.080500
#
#                           gamma
# trade_date expirDate
# 2019-11-21 2020-04-17  0.087538
# 2019-11-22 2020-04-17  0.092492
# 2019-11-25 2020-04-17  0.091385
# 2019-11-26 2020-04-17  0.088543
# 2019-11-27 2020-04-17  0.090719
# 2019-11-29 2020-04-17  0.113400
# 2019-12-02 2020-04-17  0.109854
# 2019-12-03 2020-04-17  0.108773
# 2019-12-04 2020-04-17  0.088796
# 2019-12-05 2020-04-17  0.087281
# 2019-12-06 2020-04-17  0.081137
# 2019-12-09 2020-04-17  0.082000
# 2019-12-10 2020-04-17  0.079013
# 2019-12-11 2020-04-17  0.082792
# 2019-12-12 2020-04-17  0.078439
# 2019-12-13 2020-04-17  0.074918
# 2019-12-16 2020-04-17  0.069697
# 2019-12-17 2020-04-17  0.064727
# 2019-12-18 2020-04-17  0.061387
# 2019-12-19 2020-04-17  0.062882
# 2019-12-20 2020-04-17  0.067963
# 2019-12-23 2020-04-17  0.063053
# 2019-12-24 2020-04-17  0.059862
# 2019-12-26 2020-04-17  0.054073
# 2019-12-27 2020-04-17  0.052735
# 2019-12-30 2020-04-17  0.055218
# 2019-12-31 2020-04-17  0.059114
# 2020-01-02 2020-04-17  0.058594
# 2020-01-03 2020-04-17  0.044788
# 2020-01-06 2020-04-17  0.047449
# ...                         ...
# 2020-01-31 2020-04-17  0.175221
# 2020-02-03 2020-04-17  0.200500
# 2020-02-04 2020-04-17  0.212466
# 2020-02-05 2020-04-17  0.194607
# 2020-02-06 2020-04-17  0.195973
# 2020-02-07 2020-04-17  0.215075
# 2020-02-10 2020-04-17  0.228713
# 2020-02-11 2020-04-17  0.229897
# 2020-02-12 2020-04-17  0.205280
# 2020-02-13 2020-04-17  0.196087
# 2020-02-14 2020-04-17  0.194000
# 2020-02-18 2020-04-17  0.201000
# 2020-02-19 2020-04-17  0.175000
# 2020-02-20 2020-04-17  0.164000
# 2020-02-21 2020-04-17  0.176000
# 2020-02-24 2020-04-17  0.219000
# 2020-02-25 2020-04-17  0.237000
# 2020-02-26 2020-04-17  0.259000
# 2020-02-27 2020-04-17  0.267000
# 2020-02-28 2020-04-17  0.255000
# 2020-03-02 2020-04-17  0.262000
# 2020-03-03 2020-04-17  0.246000
# 2020-03-04 2020-04-17  0.256000
# 2020-03-05 2020-04-17  0.258000
# 2020-03-06 2020-04-17  0.198000
# 2020-03-09 2020-04-17  0.091000
# 2020-03-10 2020-04-17  0.104000
# 2020-03-11 2020-04-17  0.080000
# 2020-03-12 2020-04-17  0.079000
# 2020-03-13 2020-04-17  0.085000
#
# [77 rows x 8 columns]
